# %% [markdown]
# <a href="https://colab.research.google.com/github/jryanb0b/jryanb0b/blob/main/u11n1_self_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programming with Self-Attention

# %% [markdown]
# This notebook is based on the [blog post by Sasha Rush](https://srush.github.io/raspy/).

# %%
# !pip install -qqq git+https://github.com/chalk-diagrams/chalk git+https://github.com/srush/RASPy
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.5 MB/s eta 0:00:00
#   Building wheel for chalk-diagrams (pyproject.toml) ... done
#   Building wheel for raspy (setup.py) ... done
#   Building wheel for planar (setup.py) ... done

# %%
from raspy import *
import raspy.visualize
from chalk import *

# %% [markdown]
# # Where We're Going

# %%
raspy.visualize.EXAMPLE = 'hello'
def flip():
    length = (key(1) == query(1)).value(1).name("length")
    flipped = (key(length - indices - 1) == query(indices)).value(tokens).name("other_token")
    return flipped
flip()
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %% [markdown]
# # Section 1: Feed-Forward Network

# %%
(tokens == 'l')
# Out:
# [False, False, True, True, False]

# %%
((indices > 1) & (indices <= 3))
# Out:
# [False, False, True, True, False]

# %%
where(indices >= 2, "y", tokens)
# Out:
# ['h', 'e', 'y', 'y', 'y']

# %% [markdown]
# Exercise:
#
# - Replace every 'e' with 'A'
# - Replace the first token with 'B'
# - For everything else (i.e., that isn't an e or the first token) output 'C'

# %%
(where(tokens == 'e', "A", where(indices == 0, "B", "C")))
# Out:
# ['B', 'A', 'C', 'C', 'C']

# %% [markdown]
# # Section 2: Keys and Queries

# %%
key(tokens)

# %%
query(tokens)
# Out:
# query(out)('hello')=
# h |
# e |
# l |
# l |
# o |

# %%
key(tokens) == query(tokens)
# Out:
# Selector Layer 0
#         0 1 2 3 4
#         |h e l l o|
#         h e l l o
#         |---------|
# 0 h h | 1
# 1 e e |   1
# 2 l l |     1 1
# 3 l l |     1 1
# 4 o o |         1

# %% [markdown]
# Scalars broadcast to the length of the sequence.

# %%
key(tokens) == query('e')
# Out:
# Selector Layer 0
#         0 1 2 3 4
#         |h e l l o|
#         e e e e e
#         |---------|
# 0 h h |
# 1 e e | 1 1 1 1 1
# 2 l l |
# 3 l l |
# 4 o o |

# %%
key('e') == query(tokens)
# Out:
# Selector Layer 0
#         0 1 2 3 4
#         |h e l l o|
#         h e l l o
#         |---------|
# 0 h e |   1
# 1 e e |   1
# 2 l e |   1
# 3 l e |   1
# 4 o e |   1

# %% [markdown]
# **Example**: Count `e`s.

# %%
(key('l') == query(tokens)).value(1)
# Out:
# [0, 0, 5, 5, 0]

# %% [markdown]
# Exercise: Explain to your partners what the values on the *top* and *left* of the grid mean. (You might also think about the bottom and right values, but don't worry if you don't get them quite yet.)

# %% [markdown]
# Exercise: predict the result of the following cell. Discuss your prediction with your partners. Then, uncomment it and check your prediction. Discuss what you learned.

# %%
(key(tokens) == query('e')).value(1)
# Out:
# [1, 1, 1, 1, 1]

# %% [markdown]
# Exercise: `length`.
#
# 1. Explain to your partners: why does the following code compute the length of the input sequence?
# 2. Change it so that only the first token gets the sequence length.

# %%
(key(0) == query(indices)).value(1)
# Out:
# [5, 0, 0, 0, 0]

# %% [markdown]
# Exercise: **histogram**.
#
# For each token, output how many times that token occurs in the sequence.

# %%
(key(tokens) == query(tokens)).value(1)
# Out:
# [1, 1, 2, 2, 1]

# %% [markdown]
# Example: a selector that matches each output position to all earlier input positions.

# %%
before = key(indices) < query(indices)
before
# Out:
# Selector Layer 0
#         0 1 2 3 4
#         |h e l l o|
#         0 1 2 3 4
#         |---------|
# 0 h 0 |   1 1 1 1
# 1 e 1 |     1 1 1
# 2 l 2 |       1 1
# 3 l 3 |         1
# 4 o 4 |

# %% [markdown]
# # Section 3: Values (other than 1)

# %%
def cumsum(seq=tokens):
    return (key(indices) <= query(indices)).value(seq).name("cumsum")
cumsum().input([3, 1, -2, 3, 1])
# Out:
# [3, 4, 2, 5, 6]

# %% [markdown]
# Exercise: Explain to your partners what the values on the *bottom* and *right* of the grid mean.

# %% [markdown]
# Exercise: pattern detect
#
# Detect all instances of vowel-consonant.

# %%
vowel = tokens.map(lambda tok: tok in 'aeiou')
not_vowel = tokens.map(lambda tok: tok in 'bcdfghjklmnpqrstvwxyz')
# consonant_vowel = vowel.map(lambda tok == )
# not_vowel

# %%
example = list("This weekend")

# %%
# prev_was_vowel & not_vowel

left_of_vowels = ((key(indices) == query(indices -1)).value(vowel))#.input(example)
vowels = vowel#.input(example)
not_vowels = not_vowel#.input(example)

# left_of_vowels
not_vowel
consonants_after_vowels = (key(left_of_vowels) == query(not_vowel)).input(example)
consonants_after_vowels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-76847b857bf8> in <cell line: 9>()
#       7 # left_of_vowels
#       8 not_vowel
# ----> 9 consonants_after_vowels = ((key(left_of_vowels) == query(not_vowel)).input(example))
#      10 consonants_after_vowels
#
# AttributeError: 'Selector' object has no attribute 'input'

# %%
p1 = ((key(indices) == query(indices -1)).value(vowel))
(key(p1) == query(indices))
# Out:
# Selector Layer 1
#         0 1 2 3 4
#         |h e l l o|
#         0 1 2 3 4
#         |---------|
# 0 h 0 | 1
# 1 e 0 | 1
# 2 l 1 |   1
# 3 l 0 | 1
# 4 o 0 | 1

# %%
prev_was_vowel & not_vowel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1fb38b997861> in <cell line: 1>()
# ----> 1 prev_was_vowel & not_vowel
#
# NameError: name 'prev_was_vowel' is not defined
